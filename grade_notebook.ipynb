# %%
import csv, os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import style
!

# %%
# f = open('data.csv')
# csv_f = csv.reader(f)

data = [10, 44, 90, 30]
register = [0, 1, 2, 3]

df = pd.read_csv('data.csv', delimiter=',', index_col=0)
df
#for row in csv_f:
    #rows.append(row)

# plt.figure(figsize = (8,4))
# plt.bar(register, data, width = 0.8, color = ("m", "r", "b", "g"))
# plt.show()
# Out:
#                   Term  Test Instructor LetterGrade  PercentGrade   Q1   Q2  \
# Participant_Code
# KEY                NaN   NaN        NaN         NaN           NaN    E    D
# NaN                NaN   NaN        NaN         NaN           NaN  NaN  NaN
# 22                 1.0  Post          A           D         54.83    D    C
# 50                 1.0   Pre          A           F         12.41    A  NaN
# 82                 1.0   Pre          A          B+         84.94    C    C
# ...                ...   ...        ...         ...           ...  ...  ...
# 37                 2.0  Post          B           A         97.72    A    D
# 42                 2.0  Post          B          B+         87.81    D  NaN
# 42                 2.0   Pre          B          B+         87.81    C    C
# 79                 2.0   Pre          B          B+         86.68    D  NaN
# 79                 2.0  Post          B          B+         86.68    B    E
#
# ...

# %%
df['PercentGrade'].describe()
# Out:
# count    147.000000
# mean      80.805986
# std       22.671825
# min        0.000000
# 25%       73.620000
# 50%       87.810000
# 75%       97.170000
# max      106.000000
# Name: PercentGrade, dtype: float64

# %%
df['PercentGrade'].plot(kind="box")

# %%
df['PercentGrade'].plot(kind='hist', title='PercentGrade');

# %%
df.boxplot(column='PercentGrade', by='Test');

# %%
df.loc[0:0, 'Q1':'Q27']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-55777f3c9af7> in <module>
# ----> 1 df.loc[0:0, 'Q1':'Q27']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1286                 continue
#    1287
# -> 1288             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1289
#    1290         return retval
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909         if isinstance(key, slice):
# ...
